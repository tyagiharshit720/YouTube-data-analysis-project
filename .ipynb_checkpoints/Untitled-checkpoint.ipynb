# %%
from googleapiclient.discovery import build
import pandas as pd
from IPython.display import JSON

# %%
api_key= 'AIzaSyBOu6fjlDyDAB8o-wy8GjFMwJbRhc-nKnw'
channel_ids=['UCO6ad5gPohM8RuXrYqX8Gkw',]

# %%
api_service_name = "youtube"
api_version = "v3"

# Get credentials and create an API client
youtube = build(
    api_service_name, api_version, developerKey=api_key)

# %%
def get_channel_stats(youtube, channel_ids):
    

    all_data = []
    
    request = youtube.channels().list(
        part="snippet,contentDetails,statistics",
        id=','.join(channel_ids)
    )
    response = request.execute()

    # loop through items
    for item in response['items']:
        data = {'channelName': item['snippet']['title'],
                'subscribers': item['statistics']['subscriberCount'],
                'views': item['statistics']['viewCount'],
                'totalVideos': item['statistics']['videoCount'],
                'playlistId': item['contentDetails']['relatedPlaylists']['uploads']
        }
        
        all_data.append(data)
        
    return pd.DataFrame(all_data)

# %%
channel_stats = get_channel_stats(youtube, channel_ids)
channel_stats
# Out:
#     channelName subscribers  views totalVideos                playlistId
# 0  FIRE INFIELD         590  87888          61  UUO6ad5gPohM8RuXrYqX8Gkw

# %%
playlist_id="UUO6ad5gPohM8RuXrYqX8Gkw"
def get_video_ids(youtube, playlist_id):
    
    video_ids = []
    
    request = youtube.playlistItems().list(
        part="snippet,contentDetails",
        playlistId=playlist_id,
        maxResults = 50
    )
    response = request.execute()
    
    for item in response['items']:
        video_ids.append(item['contentDetails']['videoId'])
        
    next_page_token = response.get('nextPageToken')
    while next_page_token is not None:
        request = youtube.playlistItems().list(
                    part='contentDetails',
                    playlistId = playlist_id,
                    maxResults = 50,
                    pageToken = next_page_token)
        response = request.execute()

        for item in response['items']:
            video_ids.append(item['contentDetails']['videoId'])

        next_page_token = response.get('nextPageToken')
        
    return video_ids
video_ids = get_video_ids(youtube, playlist_id)
len(video_ids)


video_ids = get_video_ids(youtube, playlist_id)
len(video_ids)
# Out:
# 61

# %%
def get_video_details(youtube, video_ids):

    all_video_info = []
    
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=','.join(video_ids[i:i+50])
        )
        response = request.execute() 

        for video in response['items']:
            stats_to_keep = {'snippet': ['channelTitle', 'title', 'description', 'tags', 'publishedAt'],
                             'statistics': ['viewCount', 'likeCount', 'favouriteCount', 'commentCount'],
                             'contentDetails': ['duration', 'definition', 'caption']
                            }
            video_info = {}
            video_info['video_id'] = video['id']

            for k in stats_to_keep.keys():
                for v in stats_to_keep[k]:
                    try:
                        video_info[v] = video[k][v]
                    except:
                        video_info[v] = None

            all_video_info.append(video_info)
    
    return pd.DataFrame(all_video_info)


video_df = get_video_details(youtube, video_ids)
video_df
# Out:
#        video_id  channelTitle  \
# 0   JoEdMupEc84  FIRE INFIELD
# 1   3X53vrx6rdA  FIRE INFIELD
# 2   Q8UIuli4Efs  FIRE INFIELD
# 3   J1n6IOtxvlc  FIRE INFIELD
# 4   QTn0sOsoBiM  FIRE INFIELD
# ..          ...           ...
# 56  mIOo9KsRy_k  FIRE INFIELD
# 57  GT_rpoXZzOE  FIRE INFIELD
# 58  3AZAJ87bUOo  FIRE INFIELD
# 59  loh_hHeSBHQ  FIRE INFIELD
# 60  gXLaNh0Z6ec  FIRE INFIELD
#
#                                                 title  \
# 0   BABA MOJJI BHI CID BHI ||carprank ||carliftpra...
# 1   car prank#carliftprank#Fire infield#viral#yout...
# 2   पहले केला खाओ फिर..||car prank ||carliftprank ...
# 3   car prank#car lift prank#@FIREINFIELD #shorts ...
# 4   car prank#@FIREINFIELD #shorts#viral #youtube#...
# ..                                                ...
# 56    Car prank video | ep.01 | @FIREINFIELD | #prank
# 57       Swift alignment and alloys detail | vlog - 4
# 58         Swift washing 250rs mai new hogyi | vlog 3
# 59                         Bhooke vapas aaye | vlog-2
# 60            First Vlog mai he scene hogya | vlog- 1
#
#                                           description  \
# 0   Hey everyone welcome to our new channel please...
# 1   Hey everyone welcome to our new channel please...
# 2   Hey everyone welcome to our new channel please...
# 3   Hey everyone welcome to our new channel @FIREI...
# 4   Hey everyone welcome to our new channel @FIREI...
# ..                                                ...
# 56  Hey everyone welcome to our new channel please...
# 57  Hey everyone welcome to our new channel please...
# 58  Hey everyone welcome to our new channel please...
# 59  Hey everyone welcome to our new channel please...
# 60  Hey everyone welcome to our new channel please...
#
#                                                  tags           publishedAt  \
# 0   [CARPRANK, carprank, car prank, car video, car...  2023-10-22T11:50:35Z
# 1   [car prank, carprankkannada, carvideo, comedy,...  2023-10-19T16:27:45Z
# 2   [@fire infield, YouTube, car folling, car lift...  2023-10-19T08:03:53Z
# 3                                                None  2023-10-16T07:58:23Z
# 4   [car prank, CARPRANK, @Fire infield, carfollin...  2023-10-15T07:57:03Z
# ..                                                ...                   ...
# 56                                               None  2023-07-30T16:56:40Z
# 57                                               None  2023-07-28T08:59:50Z
# 58                                               None  2023-07-21T11:48:55Z
# 59                                               None  2023-07-19T09:18:48Z
# 60                                               None  2023-07-18T10:14:58Z
#
#    viewCount likeCount favouriteCount commentCount  duration definition  \
# 0         82         7           None            0     PT59S         hd
# 1        130        12           None            2     PT59S         hd
# 2        406        11           None            3  PT10M14S         hd
# 3        118         8           None            0      PT1M         hd
# 4       2547        54           None            0     PT59S         hd
# ..       ...       ...            ...          ...       ...        ...
# 56      1396        68           None           15  PT10M16S         hd
# 57       230        24           None            0  PT12M47S         hd
# 58       448        21           None            2     PT14M         hd
# 59       156        23           None            4   PT8M12S         hd
# 60       209        34           None            1   PT5M25S         hd
#
#    caption
# 0    false
# 1    false
# 2    false
# 3    false
# 4    false
# ..     ...
# 56   false
# 57   false
# 58   false
# 59   false
# 60   false
#
# [61 rows x 13 columns]
